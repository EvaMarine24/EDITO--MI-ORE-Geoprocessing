# %% [markdown]
# # Image_to_Shapefile
# This script is used to clip your bathymetry file to desired depth, 150m and 80m was chosen to include onshore and offshore wind, from an Image server.

# %%
# !pip install arcgis
# !pip install rasterio
# !pip install geopandas
# Out:
# Requirement already satisfied: arcgis in /opt/conda/lib/python3.12/site-packages (2.4.1.3)
# Requirement already satisfied: pillow in /opt/conda/lib/python3.12/site-packages (from arcgis) (11.3.0)
# Requirement already satisfied: urllib3<3,>=2.1.0 in /opt/conda/lib/python3.12/site-packages (from arcgis) (2.5.0)
# Requirement already satisfied: cachetools in /opt/conda/lib/python3.12/site-packages (from arcgis) (6.2.1)
# Requirement already satisfied: lxml in /opt/conda/lib/python3.12/site-packages (from arcgis) (6.0.0)
# Requirement already satisfied: cryptography in /opt/conda/lib/python3.12/site-packages (from arcgis) (45.0.5)
# Requirement already satisfied: pandas<2.3.0,>=2.0.0 in /opt/conda/lib/python3.12/site-packages (from arcgis) (2.2.3)
# Requirement already satisfied: numpy<2,>=1.21.6 in /opt/conda/lib/python3.12/site-packages (from arcgis) (1.26.4)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.12/site-packages (from arcgis) (3.10.3)
# Requirement already satisfied: keyring>=23.3.0 in /opt/conda/lib/python3.12/site-packages (from arcgis) (25.6.0)
# Requirement already satisfied: pylerc in /opt/conda/lib/python3.12/site-packages (from arcgis) (4.0)
# Requirement already satisfied: ujson>=3 in /opt/conda/lib/python3.12/site-packages (from arcgis) (5.11.0)
# Requirement already satisfied: truststore>=0.10.0 in /opt/conda/lib/python3.12/site-packages (from arcgis) (0.10.1)
# Requirement already satisfied: geomet in /opt/conda/lib/python3.12/site-packages (from arcgis) (1.1.0)
# Requirement already satisfied: requests<3,>=2.32.3 in /opt/conda/lib/python3.12/site-packages (from arcgis) (2.32.4)
# Requirement already satisfied: requests-oauthlib in /opt/conda/lib/python3.12/site-packages (from arcgis) (2.0.0)
# Requirement already satisfied: requests_toolbelt in /opt/conda/lib/python3.12/site-packages (from arcgis) (1.0.0)
# Requirement already satisfied: pyspnego>=0.8.0 in /opt/conda/lib/python3.12/site-packages (from arcgis) (0.12.0)
# Requirement already satisfied: dask<2025.1.0,>=2024.12.1 in /opt/conda/lib/python3.12/site-packages (from dask[dataframe]<2025.1.0,>=2024.12.1->arcgis) (2024.12.1)
# Requirement already satisfied: matplotlib-inline in /opt/conda/lib/python3.12/site-packages (from arcgis) (0.1.7)
# Requirement already satisfied: pyarrow<17,>=16 in /opt/conda/lib/python3.12/site-packages (from arcgis) (16.1.0)
# Requirement already satisfied: puremagic<2,>=1.15 in /opt/conda/lib/python3.12/site-packages (from arcgis) (1.30)
# Requirement already satisfied: pydantic<3,>=2.8.2 in /opt/conda/lib/python3.12/site-packages (from arcgis) (2.11.7)
# Requirement already satisfied: networkx<4,>=3.3 in /opt/conda/lib/python3.12/site-packages (from arcgis) (3.5)
# Requirement already satisfied: websocket-client<2.0.0,>=1.2.3 in /opt/conda/lib/python3.12/site-packages (from arcgis) (1.8.0)
# Requirement already satisfied: click>=8.1 in /opt/conda/lib/python3.12/site-packages (from dask<2025.1.0,>=2024.12.1->dask[dataframe]<2025.1.0,>=2024.12.1->arcgis) (8.2.1)
# Requirement already satisfied: cloudpickle>=3.0.0 in /opt/conda/lib/python3.12/site-packages (from dask<2025.1.0,>=2024.12.1->dask[dataframe]<2025.1.0,>=2024.12.1->arcgis) (3.1.1)
# Requirement already satisfied: fsspec>=2021.09.0 in /opt/conda/lib/python3.12/site-packages (from dask<2025.1.0,>=2024.12.1->dask[dataframe]<2025.1.0,>=2024.12.1->arcgis) (2025.5.1)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.12/site-packages (from dask<2025.1.0,>=2024.12.1->dask[dataframe]<2025.1.0,>=2024.12.1->arcgis) (25.0)
# Requirement already satisfied: partd>=1.4.0 in /opt/conda/lib/python3.12/site-packages (from dask<2025.1.0,>=2024.12.1->dask[dataframe]<2025.1.0,>=2024.12.1->arcgis) (1.4.2)
# Requirement already satisfied: pyyaml>=5.3.1 in /opt/conda/lib/python3.12/site-packages (from dask<2025.1.0,>=2024.12.1->dask[dataframe]<2025.1.0,>=2024.12.1->arcgis) (6.0.2)
# Requirement already satisfied: toolz>=0.10.0 in /opt/conda/lib/python3.12/site-packages (from dask<2025.1.0,>=2024.12.1->dask[dataframe]<2025.1.0,>=2024.12.1->arcgis) (1.0.0)
# Requirement already satisfied: dask-expr<1.2,>=1.1 in /opt/conda/lib/python3.12/site-packages (from dask[dataframe]<2025.1.0,>=2024.12.1->arcgis) (1.1.21)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.12/site-packages (from pandas<2.3.0,>=2.0.0->arcgis) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.12/site-packages (from pandas<2.3.0,>=2.0.0->arcgis) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.12/site-packages (from pandas<2.3.0,>=2.0.0->arcgis) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/conda/lib/python3.12/site-packages (from pydantic<3,>=2.8.2->arcgis) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /opt/conda/lib/python3.12/site-packages (from pydantic<3,>=2.8.2->arcgis) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /opt/conda/lib/python3.12/site-packages (from pydantic<3,>=2.8.2->arcgis) (4.14.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in /opt/conda/lib/python3.12/site-packages (from pydantic<3,>=2.8.2->arcgis) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.12/site-packages (from requests<3,>=2.32.3->arcgis) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.12/site-packages (from requests<3,>=2.32.3->arcgis) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.12/site-packages (from requests<3,>=2.32.3->arcgis) (2025.6.15)
# Requirement already satisfied: SecretStorage>=3.2 in /opt/conda/lib/python3.12/site-packages (from keyring>=23.3.0->arcgis) (3.4.0)
# Requirement already satisfied: jeepney>=0.4.2 in /opt/conda/lib/python3.12/site-packages (from keyring>=23.3.0->arcgis) (0.9.0)
# Requirement already satisfied: jaraco.classes in /opt/conda/lib/python3.12/site-packages (from keyring>=23.3.0->arcgis) (3.4.0)
# Requirement already satisfied: jaraco.functools in /opt/conda/lib/python3.12/site-packages (from keyring>=23.3.0->arcgis) (4.3.0)
# Requirement already satisfied: jaraco.context in /opt/conda/lib/python3.12/site-packages (from keyring>=23.3.0->arcgis) (6.0.1)
# Requirement already satisfied: locket in /opt/conda/lib/python3.12/site-packages (from partd>=1.4.0->dask<2025.1.0,>=2024.12.1->dask[dataframe]<2025.1.0,>=2024.12.1->arcgis) (1.0.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas<2.3.0,>=2.0.0->arcgis) (1.17.0)
# Requirement already satisfied: cffi>=1.14 in /opt/conda/lib/python3.12/site-packages (from cryptography->arcgis) (1.17.1)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.12/site-packages (from cffi>=1.14->cryptography->arcgis) (2.22)
# Requirement already satisfied: more-itertools in /opt/conda/lib/python3.12/site-packages (from jaraco.classes->keyring>=23.3.0->arcgis) (10.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.12/site-packages (from matplotlib->arcgis) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.12/site-packages (from matplotlib->arcgis) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.12/site-packages (from matplotlib->arcgis) (4.58.5)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.12/site-packages (from matplotlib->arcgis) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.12/site-packages (from matplotlib->arcgis) (3.2.3)
# Requirement already satisfied: traitlets in /opt/conda/lib/python3.12/site-packages (from matplotlib-inline->arcgis) (5.14.3)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/conda/lib/python3.12/site-packages (from requests-oauthlib->arcgis) (3.3.1)
# Requirement already satisfied: rasterio in /opt/conda/lib/python3.12/site-packages (1.4.3)
# Requirement already satisfied: affine in /opt/conda/lib/python3.12/site-packages (from rasterio) (2.4.0)
# Requirement already satisfied: attrs in /opt/conda/lib/python3.12/site-packages (from rasterio) (25.3.0)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.12/site-packages (from rasterio) (2025.6.15)
# Requirement already satisfied: click>=4.0 in /opt/conda/lib/python3.12/site-packages (from rasterio) (8.2.1)
# Requirement already satisfied: cligj>=0.5 in /opt/conda/lib/python3.12/site-packages (from rasterio) (0.7.2)
# Requirement already satisfied: numpy>=1.24 in /opt/conda/lib/python3.12/site-packages (from rasterio) (1.26.4)
# Requirement already satisfied: click-plugins in /opt/conda/lib/python3.12/site-packages (from rasterio) (1.1.1.2)
# Requirement already satisfied: pyparsing in /opt/conda/lib/python3.12/site-packages (from rasterio) (3.2.3)
# Requirement already satisfied: geopandas in /opt/conda/lib/python3.12/site-packages (1.1.1)
# Requirement already satisfied: numpy>=1.24 in /opt/conda/lib/python3.12/site-packages (from geopandas) (1.26.4)
# Requirement already satisfied: pyogrio>=0.7.2 in /opt/conda/lib/python3.12/site-packages (from geopandas) (0.11.1)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.12/site-packages (from geopandas) (25.0)
# Requirement already satisfied: pandas>=2.0.0 in /opt/conda/lib/python3.12/site-packages (from geopandas) (2.2.3)
# Requirement already satisfied: pyproj>=3.5.0 in /opt/conda/lib/python3.12/site-packages (from geopandas) (3.7.1)
# Requirement already satisfied: shapely>=2.0.0 in /opt/conda/lib/python3.12/site-packages (from geopandas) (2.1.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.12/site-packages (from pandas>=2.0.0->geopandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.12/site-packages (from pandas>=2.0.0->geopandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.12/site-packages (from pandas>=2.0.0->geopandas) (2025.2)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.12/site-packages (from pyogrio>=0.7.2->geopandas) (2025.6.15)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->geopandas) (1.17.0)

# %%
from arcgis.raster import ImageryLayer
from arcgis.gis import GIS
from rasterio.transform import from_bounds
from rasterio.features import shapes
from shapely.geometry import shape
from itertools import product
import multiprocessing as mp
import geopandas as gpd
import numpy as np
import os
import pathlib

# Get the user's Downloads folder
downloads_path = str(pathlib.Path.home() / "Downloads")


def worker(args):
    ''' Tasks to be carried out by each CPU for parallelization '''
    j, arg = args
    i, x = arg
    lat = np.arange( 48, 57, .05)

    url = "https://image.marine.ie/arcgis/rest/services/INFOMAR/AllSurvey/ImageServer" ######## Specify URL here
    img_layer = ImageryLayer(url)
    
    point = {"x": x, "y": lat[j], "spatialReference": {"wkid": 4326}}

    try:
        # Retrieve bathymetry for this longitude-latitude point
        sample = img_layer.get_samples(geometry=point, 
                                       geometry_type='esriGeometryPoint',  
                                       return_first_value_only=True)
        mpdata[j] = float(sample[0]['value'])
    except Exception:
        mpdata[j] = -999999
    
def init(A):
    global mpdata
    mpdata = A

def main():
    ''' Define raster grid '''
    lon = np.arange(-12, -5, .05); L = len(lon) # Longitude
    lat = np.arange( 48, 57, .05); M = len(lat) # Latitude
    # Initialize bathymetry
    H = -999999*np.ones((L, M))
    
    # Shared-memory array
    mpdata = mp.Array('d', [1]*M)
    
    for i, x in enumerate(lon):
        print('Procesing longitude %.2f' % x)
        # Wrap arguments needed by the workers (longitude)
        args = (i, x)
        
        # Start parallel loop
        pool = mp.Pool(initializer=init, initargs=(mpdata,))
        pool.imap(worker, product(range(M,), (args,)) )
        pool.close(); pool.join()

        # Write bathymetry
        H[i, :] = mpdata
        
    create_shapefile_from_raster(lon, lat, H)

def create_shapefile_from_raster(lon, lat, H):
    ''' Convert gridded bathymetry into shapefile '''

    print('Creating shapefile...')

    # Preparing  data for shapefile creation
    data = H.T; longitude = np.squeeze(lon); latitude = np.squeeze(lat)

    # This seems to be required to get the right orientation of the bathymetry
    data = np.flip(data, axis=0)

    # Mask below 150 meters and missing values
    mask = np.logical_or(data > 100, data < -80); masked_array = np.ma.masked_array(data, mask=mask)

    L, M = masked_array.shape

    # Create affine transform from bounds
    transform = from_bounds(longitude.min(),
                            latitude.min(),
                            longitude.max(),
                            latitude.max(), M, L)

    # Binary mask: 1 for unmasked, 0 for masked
    binary_mask = (~masked_array.mask).astype(np.uint8)

    # Extract polygons
    polygons = [shape(geom) for geom, value in shapes(binary_mask, mask=None, transform=transform) if value == 1]

    # Create GeoDataFrame
    gdf = gpd.GeoDataFrame(geometry=polygons, crs="EPSG:4326")

    # Save to shapefile
    #os.makedirs("INFOMAR-150", exist_ok=True)

    # Create a subfolder for your output
    output_folder = os.path.join(downloads_path, "INFOMAR-80")
    os.makedirs(output_folder, exist_ok=True)

    # Full path to shapefile
    output_path = os.path.join(output_folder, "INFOMAR-80.shp")

    # Save to Downloads
    gdf.to_file(output_path)

    #print(f"Shapefile saved to: {output_path}")
    #gdf.to_file("INFOMAR-150/INFOMAR-150.shp") ############################################################ GL to save to S3 #####################################################################

    print('INFOMAR-80.shp created')

    return output_folder

    from upload_model import upload_model_to_s3_bucket
    upload_model_to_s3_bucket(output_folder)
    print("Upload finished.")




######## Extra cell below to perform the same function but only converting image to raster to shapefile - no masking.

# %% [markdown]
# ## Download to S3 Bucket

# %%
import os

dir_output = os.path.abspath(pwd) #f'./data'
print(dir_output)

from upload_model import upload_model_to_s3_bucket

upload_model_to_s3_bucket(dir_output)

# %% [markdown]
# ## Download to Local Machine

# %%
import base64
from IPython.display import HTML

zip_path = "/home/jovyan/Downloads/INFOMAR-80.zip"

# Read the ZIP file
with open(zip_path, "rb") as f:
    data = f.read()

# Encode the file in Base64 and build a browser download link
b64 = base64.b64encode(data).decode()
payload = f"data:application/zip;base64,{b64}"

html = f"""
<a href="{payload}" download="INFOMAR-80.zip"
   style="background: #007bff; color: white; padding: 10px 16px; 
          border-radius: 6px; text-decoration: none; font-weight: bold;">
   ⬇️ Click here to download INFOMAR-80.zip
</a>
"""

display(HTML(html))
